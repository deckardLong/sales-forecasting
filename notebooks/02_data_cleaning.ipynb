# %% [markdown]
# ## **0. Import Libraries**

# %%
import os
import sys
sys.path.append(os.path.abspath('..'))

# %%
from src import preprocessing

# %% [markdown]
# ## **1. Data after Cleaning**

# %%
sales, cal, prices = preprocessing.load_data()

# %%
sales.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  d_1907  d_1908  \
# 0       CA    0    0    0    0  ...       1       3       0       1       1
# 1       CA    0    0    0    0  ...       0       0       0       0       0
# 2       CA    0    0    0    0  ...       2       1       2       1       1
# 3       CA    0    0    0    0  ...       1       0       5       4       1
# 4       CA    0    0    0    0  ...       2       1       1       0       1
#
#    d_1909  d_1910  d_1911  d_1912  d_1913
# ...

# %%
sales = preprocessing.clean_sales(sales)

# %%
sales.head(10)
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
# 5  HOBBIES_1_006_CA_1_validation  HOBBIES_1_006  HOBBIES_1  HOBBIES     CA_1
# 6  HOBBIES_1_007_CA_1_validation  HOBBIES_1_007  HOBBIES_1  HOBBIES     CA_1
# 7  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1
# 8  HOBBIES_1_009_CA_1_validation  HOBBIES_1_009  HOBBIES_1  HOBBIES     CA_1
# 9  HOBBIES_1_010_CA_1_validation  HOBBIES_1_010  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  sales
# 0       CA  d_1      0
# 1       CA  d_1      0
# 2       CA  d_1      0
# 3       CA  d_1      0
# ...

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 58327370 entries, 0 to 58327369
# Data columns (total 8 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   id        str
#  1   item_id   str
#  2   dept_id   str
#  3   cat_id    str
#  4   store_id  str
#  5   state_id  str
#  6   d         str
#  7   sales     int64
# dtypes: int64(1), str(7)
# memory usage: 7.2 GB

# %%
cal.head()
# Out:
#          date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0  2011-01-29     11101   Saturday     1      1  2011  d_1          NaN
# 1  2011-01-30     11101     Sunday     2      1  2011  d_2          NaN
# 2  2011-01-31     11101     Monday     3      1  2011  d_3          NaN
# 3  2011-02-01     11101    Tuesday     4      2  2011  d_4          NaN
# 4  2011-02-02     11101  Wednesday     5      2  2011  d_5          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0          NaN          NaN          NaN        0        0        0
# 1          NaN          NaN          NaN        0        0        0
# 2          NaN          NaN          NaN        0        0        0
# 3          NaN          NaN          NaN        1        1        0
# 4          NaN          NaN          NaN        1        0        1

# %%
cal = preprocessing.clean_cal(cal)
cal.head()
# Out:
#         date  wm_yr_wk    weekday  wday  month  year    d event_name_1  \
# 0 2011-01-29     11101   Saturday     1      1  2011  d_1     No_Event
# 1 2011-01-30     11101     Sunday     2      1  2011  d_2     No_Event
# 2 2011-01-31     11101     Monday     3      1  2011  d_3     No_Event
# 3 2011-02-01     11101    Tuesday     4      2  2011  d_4     No_Event
# 4 2011-02-02     11101  Wednesday     5      2  2011  d_5     No_Event
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI
# 0     No_Event     No_Event     No_Event        0        0        0
# 1     No_Event     No_Event     No_Event        0        0        0
# 2     No_Event     No_Event     No_Event        0        0        0
# 3     No_Event     No_Event     No_Event        1        1        0
# 4     No_Event     No_Event     No_Event        1        0        1

# %%
cal.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1969 entries, 0 to 1968
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1969 non-null   datetime64[us]
#  1   wm_yr_wk      1969 non-null   int64
#  2   weekday       1969 non-null   str
#  3   wday          1969 non-null   int64
#  4   month         1969 non-null   int64
#  5   year          1969 non-null   int64
#  6   d             1969 non-null   str
#  7   event_name_1  1969 non-null   str
#  8   event_type_1  1969 non-null   str
#  9   event_name_2  1969 non-null   str
#  10  event_type_2  1969 non-null   str
#  11  snap_CA       1969 non-null   int64
#  12  snap_TX       1969 non-null   int64
#  13  snap_WI       1969 non-null   int64
# dtypes: datetime64[us](1), int64(7), str(6)
# memory usage: 301.8 KB

# %%
cal['event_name_1'].value_counts()
# Out:
# event_name_1
# No_Event               1807
# SuperBowl                 6
# ValentinesDay             6
# PresidentsDay             6
# LentStart                 6
# LentWeek2                 6
# StPatricksDay             6
# Purim End                 6
# Pesach End                6
# Mother's day              6
# MemorialDay               6
# NBAFinalsStart            6
# NBAFinalsEnd              6
# Ramadan starts            6
# OrthodoxEaster            5
# Cinco De Mayo             5
# IndependenceDay           5
# Eid al-Fitr               5
# LaborDay                  5
# ColumbusDay               5
# Halloween                 5
# EidAlAdha                 5
# VeteransDay               5
# Thanksgiving              5
# Christmas                 5
# Chanukah End              5
# NewYear                   5
# OrthodoxChristmas         5
# MartinLutherKingDay       5
# Easter                    5
# Father's day              4
# Name: count, dtype: int64

# %%
preprocessing.save_cleaned_data(sales, cal, prices)

# %%
df = preprocessing.merge_files(sales, cal, prices)
df.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  sales       date  wm_yr_wk  ... month  year  event_name_1  \
# 0       CA  d_1      0 2011-01-29     11101  ...     1  2011      No_Event
# 1       CA  d_1      0 2011-01-29     11101  ...     1  2011      No_Event
# 2       CA  d_1      0 2011-01-29     11101  ...     1  2011      No_Event
# 3       CA  d_1      0 2011-01-29     11101  ...     1  2011      No_Event
# 4       CA  d_1      0 2011-01-29     11101  ...     1  2011      No_Event
#
# ...

# %%
df.isna().sum()
# Out:
# id                     0
# item_id                0
# dept_id                0
# cat_id                 0
# store_id               0
# state_id               0
# d                      0
# sales                  0
# date                   0
# wm_yr_wk               0
# weekday                0
# wday                   0
# month                  0
# year                   0
# event_name_1           0
# event_type_1           0
# event_name_2           0
# event_type_2           0
# snap_CA                0
# snap_TX                0
# snap_WI                0
# sell_price      12299413
# dtype: int64

# %%
df = preprocessing.clean_sell_prices(df)

# %%
print('Length of merged dataframe:', len(df))
# Out:
# Length of merged dataframe: 58327370

# %%
df.to_parquet('../data/merged/m5_merged.parquet', index=False)
