# %% [markdown]
# ## **0. Import Libraries**

# %%
import os
import sys
sys.path.append(os.path.abspath('..'))

# %%
import pandas as pd
import numpy as np
from src import prophet_features

# %% [markdown]
# ## **1. Feature Selection**

# %%
df = pd.read_parquet('../data/merged/m5_merged.parquet')
df.head()
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#   state_id    d  sales       date  wm_yr_wk  ... month  year  event_name_1  \
# 0       CA  d_1      0 2011-01-29     11101  ...     1  2011      No_Event
# 1       CA  d_1      0 2011-01-29     11101  ...     1  2011      No_Event
# 2       CA  d_1      0 2011-01-29     11101  ...     1  2011      No_Event
# 3       CA  d_1      0 2011-01-29     11101  ...     1  2011      No_Event
# 4       CA  d_1      0 2011-01-29     11101  ...     1  2011      No_Event
#
# ...

# %%
df = df.set_index('id')
df.head()
# Out:
#                                      item_id    dept_id   cat_id store_id  \
# id
# HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
#
#                               state_id    d  sales       date  wm_yr_wk  \
# id
# HOBBIES_1_001_CA_1_validation       CA  d_1      0 2011-01-29     11101
# HOBBIES_1_002_CA_1_validation       CA  d_1      0 2011-01-29     11101
# HOBBIES_1_003_CA_1_validation       CA  d_1      0 2011-01-29     11101
# HOBBIES_1_004_CA_1_validation       CA  d_1      0 2011-01-29     11101
# HOBBIES_1_005_CA_1_validation       CA  d_1      0 2011-01-29     11101
#
#                                 weekday  ...  month  year  event_name_1  \
# ...

# %%
df['event_name_2'].value_counts()
# Out:
# event_name_2
# No_Event          58205410
# Easter               30490
# Cinco De Mayo        30490
# OrthodoxEaster       30490
# Father's day         30490
# Name: count, dtype: int64

# %%
df = prophet_features.combine_snap_features(df)
df = prophet_features.select_features(df)

# %%
df.head(10)
# Out:
#                                      item_id store_id  sales       date  \
# id
# HOBBIES_1_001_CA_1_validation  HOBBIES_1_001     CA_1      0 2011-01-29
# HOBBIES_1_002_CA_1_validation  HOBBIES_1_002     CA_1      0 2011-01-29
# HOBBIES_1_003_CA_1_validation  HOBBIES_1_003     CA_1      0 2011-01-29
# HOBBIES_1_004_CA_1_validation  HOBBIES_1_004     CA_1      0 2011-01-29
# HOBBIES_1_005_CA_1_validation  HOBBIES_1_005     CA_1      0 2011-01-29
# HOBBIES_1_006_CA_1_validation  HOBBIES_1_006     CA_1      0 2011-01-29
# HOBBIES_1_007_CA_1_validation  HOBBIES_1_007     CA_1      0 2011-01-29
# HOBBIES_1_008_CA_1_validation  HOBBIES_1_008     CA_1     12 2011-01-29
# HOBBIES_1_009_CA_1_validation  HOBBIES_1_009     CA_1      2 2011-01-29
# HOBBIES_1_010_CA_1_validation  HOBBIES_1_010     CA_1      0 2011-01-29
#
#                               event_name_1 event_type_1 event_name_2  \
# id
# HOBBIES_1_001_CA_1_validation     No_Event     No_Event     No_Event
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 58327370 entries, HOBBIES_1_001_CA_1_validation to FOODS_3_827_WI_3_validation
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   item_id       str
#  1   store_id      str
#  2   sales         int64
#  3   date          datetime64[us]
#  4   event_name_1  str
#  5   event_type_1  str
#  6   event_name_2  str
#  7   event_type_2  str
#  8   sell_price    float64
#  9   snap          int64
# dtypes: datetime64[us](1), float64(1), int64(2), str(6)
# memory usage: 9.0 GB

# %% [markdown]
# ## **2. Feature Extraction**
